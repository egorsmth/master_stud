# %%
from svm_framework import *
from experiment_utils import ExperimentRunner
from run_experiments import run_all_experiments

run_all_experiments()
# Out:
# ================================================================================
# RUNNING COMPLETE EXPERIMENTAL SUITE
# ================================================================================
#
# ================================================================================
# EXPERIMENT 1: Basic Method Comparison (Breast Cancer Dataset)
# ================================================================================
# Original features: 30
# After dropping: 24
# After PCA: 16
# Explained variance: 0.9913
#
# ============================================================
# Training: 1. Primal GD
# ============================================================
#
# ============================================================
# Evaluating: 1. Primal GD
# ============================================================
#
# 1. Primal GD Results:
#   Converged: True
#   Iterations: 458
#   Wall time: 0.005s
#   Train accuracy: 0.9912
#   Test accuracy: 0.9473
#   Test F1: 0.9570
#
# ============================================================
# Training: 2. Dual Projection (Standard GD)
# ============================================================
#
# ============================================================
# Evaluating: 2. Dual Projection (Standard GD)
# ============================================================
#
# 2. Dual Projection (Standard GD) Results:
#   Converged: True
#   Iterations: 952
#   Wall time: 0.126s
#   Train accuracy: 0.9737
#   Test accuracy: 0.9495
#   Test F1: 0.9568
#   Support vectors: 40
#   KKT violation: 5.64e+01
#   Final constraint violation: 3.94e-02
#
# ============================================================
# Training: 3. Dual Projection (Nesterov)
# ============================================================
#
# ============================================================
# Evaluating: 3. Dual Projection (Nesterov)
# ============================================================
#
# 3. Dual Projection (Nesterov) Results:
#   Converged: True
#   Iterations: 84
#   Wall time: 0.011s
#   Train accuracy: 0.9474
#   Test accuracy: 0.9297
#   Test F1: 0.9403
#   Support vectors: 49
#   KKT violation: 2.30e+02
#   Final constraint violation: 1.84e-01
#
# ============================================================
# Training: 4. Dual Penalty (Standard GD)
# ============================================================
#
# ============================================================
# Evaluating: 4. Dual Penalty (Standard GD)
# ============================================================
#
# 4. Dual Penalty (Standard GD) Results:
#   Converged: False
#   Iterations: 2000
#   Wall time: 0.254s
#   Train accuracy: 0.7018
#   Test accuracy: 0.9055
#   Test F1: 0.9135
#   Support vectors: 28
#   KKT violation: 6.99e+01
#   Final constraint violation: 5.49e-01
#
# ============================================================
# Training: 5. Dual Penalty (Nesterov)
# ============================================================
# /home/geoh/personal/master_stud/.venv/lib/python3.13/site-packages/numpy/linalg/_linalg.py:2792: RuntimeWarning: overflow encountered in dot
#   sqnorm = x.dot(x)
# ============================================================
# Evaluating: 5. Dual Penalty (Nesterov)
# ============================================================
#
# 5. Dual Penalty (Nesterov) Results:
#   Converged: False
#   Iterations: 2000
#   Wall time: 0.258s
#   Train accuracy: 0.8421
#   Test accuracy: 0.9143
#   Test F1: 0.9249
#   Support vectors: 26
#   KKT violation: 1.01e+03
#   Final constraint violation: 2.60e+00
#
# ================================================================================
# COMPARISON TABLE
# ================================================================================
#                           Method Test Acc Test F1  Iterations Time (s) Converged Num SV KKT Viol
#                     1. Primal GD   0.9473  0.9570         458    0.005         ✓      -        -
# 2. Dual Projection (Standard GD)   0.9495  0.9568         952    0.126         ✓     40 5.64e+01
#    3. Dual Projection (Nesterov)   0.9297  0.9403          84    0.011         ✓     49 2.30e+02
#    4. Dual Penalty (Standard GD)   0.9055  0.9135        2000    0.254         ✗     28 6.99e+01
#       5. Dual Penalty (Nesterov)   0.9143  0.9249        2000    0.258         ✗     26 1.01e+03
# ================================================================================
# EXPERIMENT 2: Hyperparameter Search
# ================================================================================
# Original features: 30
# After dropping: 24
# After PCA: 16
# Explained variance: 0.9913
# Running grid search: 4 × 4 × 2 = 32 combinations
# C=0.001, lr=1.0e-05, momentum=0.00 → F1=0.9379
# C=0.001, lr=1.0e-05, momentum=0.90 → F1=0.9398
# C=0.001, lr=1.0e-04, momentum=0.00 → F1=0.9381
# C=0.001, lr=1.0e-04, momentum=0.90 → F1=0.9308
# C=0.001, lr=1.0e-03, momentum=0.00 → F1=0.9291
# C=0.001, lr=1.0e-03, momentum=0.90 → F1=0.9291
# C=0.001, lr=1.0e-02, momentum=0.00 → F1=0.9271
# /home/geoh/personal/master_stud/.venv/lib/python3.13/site-packages/numpy/linalg/_linalg.py:2792: RuntimeWarning: overflow encountered in dot
#   sqnorm = x.dot(x)
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:213: RuntimeWarning: overflow encountered in matmul
#   return np.ones(len(y)) - Y @ K @ Y @ alpha
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:213: RuntimeWarning: invalid value encountered in matmul
#   return np.ones(len(y)) - Y @ K @ Y @ alpha
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:323: RuntimeWarning: invalid value encountered in add
#   velocity = self.momentum * velocity + self.config.learning_rate * grad
# /home/geoh/personal/master_stud/.venv/lib/python3.13/site-packages/sklearn/externals/array_api_compat/numpy/_aliases.py:125: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype=dtype, copy=copy)
# Failed: C=0.001, lr=0.01, momentum=0.9: Input y_pred contains NaN.
# C=0.010, lr=1.0e-05, momentum=0.00 → F1=0.9511
# C=0.010, lr=1.0e-05, momentum=0.90 → F1=0.9551
# C=0.010, lr=1.0e-04, momentum=0.00 → F1=0.9551
# C=0.010, lr=1.0e-04, momentum=0.90 → F1=0.9458
# C=0.010, lr=1.0e-03, momentum=0.00 → F1=0.9478
# C=0.010, lr=1.0e-03, momentum=0.90 → F1=0.9291
# C=0.010, lr=1.0e-02, momentum=0.00 → F1=0.6533
# Failed: C=0.01, lr=0.01, momentum=0.9: Input y_pred contains NaN.
# /home/geoh/personal/master_stud/.venv/lib/python3.13/site-packages/numpy/linalg/_linalg.py:2792: RuntimeWarning: overflow encountered in dot
#   sqnorm = x.dot(x)
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:213: RuntimeWarning: overflow encountered in matmul
#   return np.ones(len(y)) - Y @ K @ Y @ alpha
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:213: RuntimeWarning: invalid value encountered in matmul
#   return np.ones(len(y)) - Y @ K @ Y @ alpha
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:323: RuntimeWarning: invalid value encountered in add
#   velocity = self.momentum * velocity + self.config.learning_rate * grad
# /home/geoh/personal/master_stud/.venv/lib/python3.13/site-packages/sklearn/externals/array_api_compat/numpy/_aliases.py:125: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype=dtype, copy=copy)
# C=0.100, lr=1.0e-05, momentum=0.00 → F1=0.9549
# C=0.100, lr=1.0e-05, momentum=0.90 → F1=0.9606
# C=0.100, lr=1.0e-04, momentum=0.00 → F1=0.9606
# C=0.100, lr=1.0e-04, momentum=0.90 → F1=0.9531
# C=0.100, lr=1.0e-03, momentum=0.00 → F1=0.9568
# C=0.100, lr=1.0e-03, momentum=0.90 → F1=0.9403
# C=0.100, lr=1.0e-02, momentum=0.00 → F1=0.5270
# /home/geoh/personal/master_stud/.venv/lib/python3.13/site-packages/numpy/linalg/_linalg.py:2792: RuntimeWarning: overflow encountered in dot
#   sqnorm = x.dot(x)
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:213: RuntimeWarning: overflow encountered in matmul
#   return np.ones(len(y)) - Y @ K @ Y @ alpha
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:213: RuntimeWarning: invalid value encountered in matmul
#   return np.ones(len(y)) - Y @ K @ Y @ alpha
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:323: RuntimeWarning: invalid value encountered in add
#   velocity = self.momentum * velocity + self.config.learning_rate * grad
# /home/geoh/personal/master_stud/.venv/lib/python3.13/site-packages/sklearn/externals/array_api_compat/numpy/_aliases.py:125: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype=dtype, copy=copy)
# Failed: C=0.1, lr=0.01, momentum=0.9: Input y_pred contains NaN.
# C=1.000, lr=1.0e-05, momentum=0.00 → F1=0.9549
# C=1.000, lr=1.0e-05, momentum=0.90 → F1=0.9605
# C=1.000, lr=1.0e-04, momentum=0.00 → F1=0.9585
# C=1.000, lr=1.0e-04, momentum=0.90 → F1=0.9603
# C=1.000, lr=1.0e-03, momentum=0.00 → F1=0.9606
# C=1.000, lr=1.0e-03, momentum=0.90 → F1=0.9354
# C=1.000, lr=1.0e-02, momentum=0.00 → F1=0.5270
# /home/geoh/personal/master_stud/.venv/lib/python3.13/site-packages/numpy/linalg/_linalg.py:2792: RuntimeWarning: overflow encountered in dot
#   sqnorm = x.dot(x)
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:213: RuntimeWarning: overflow encountered in matmul
#   return np.ones(len(y)) - Y @ K @ Y @ alpha
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:213: RuntimeWarning: invalid value encountered in matmul
#   return np.ones(len(y)) - Y @ K @ Y @ alpha
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:323: RuntimeWarning: invalid value encountered in add
#   velocity = self.momentum * velocity + self.config.learning_rate * grad
# /home/geoh/personal/master_stud/.venv/lib/python3.13/site-packages/sklearn/externals/array_api_compat/numpy/_aliases.py:125: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype=dtype, copy=copy)
# Failed: C=1.0, lr=0.01, momentum=0.9: Input y_pred contains NaN.
#
# Best parameters: {'C': 0.1, 'learning_rate': 1e-05, 'momentum': 0.9, 'use_nesterov': True}
# Best test F1: 0.9606
# ================================================================================
# EXPERIMENT 3: Learning Rate Sensitivity Analysis
# ================================================================================
# Original features: 30
# After dropping: 24
# After PCA: 16
# Explained variance: 0.9913
#
# Testing learning rate: 1.0e-05
#
# Testing learning rate: 5.0e-05
#
# Testing learning rate: 1.0e-04
#
# Testing learning rate: 5.0e-04
#
# Testing learning rate: 1.0e-03
#
# Testing learning rate: 5.0e-03
# /home/geoh/personal/master_stud/.venv/lib/python3.13/site-packages/numpy/linalg/_linalg.py:2792: RuntimeWarning: overflow encountered in dot
#   sqnorm = x.dot(x)
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:213: RuntimeWarning: overflow encountered in matmul
#   return np.ones(len(y)) - Y @ K @ Y @ alpha
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:213: RuntimeWarning: invalid value encountered in matmul
#   return np.ones(len(y)) - Y @ K @ Y @ alpha
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:323: RuntimeWarning: invalid value encountered in add
#   velocity = self.momentum * velocity + self.config.learning_rate * grad
# /home/geoh/personal/master_stud/.venv/lib/python3.13/site-packages/sklearn/externals/array_api_compat/numpy/_aliases.py:125: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype=dtype, copy=copy)
# Testing learning rate: 1.0e-02
# /home/geoh/personal/master_stud/.venv/lib/python3.13/site-packages/numpy/linalg/_linalg.py:2792: RuntimeWarning: overflow encountered in dot
#   sqnorm = x.dot(x)
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:213: RuntimeWarning: overflow encountered in matmul
#   return np.ones(len(y)) - Y @ K @ Y @ alpha
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:213: RuntimeWarning: invalid value encountered in matmul
#   return np.ones(len(y)) - Y @ K @ Y @ alpha
# /home/geoh/personal/master_stud/chat/v1/svm_framework.py:323: RuntimeWarning: invalid value encountered in add
#   velocity = self.momentum * velocity + self.config.learning_rate * grad
# /home/geoh/personal/master_stud/.venv/lib/python3.13/site-packages/sklearn/externals/array_api_compat/numpy/_aliases.py:125: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype=dtype, copy=copy)
# ================================================================================
# EXPERIMENT 4: Momentum Parameter Study
# ================================================================================
# Original features: 30
# After dropping: 24
# After PCA: 16
# Explained variance: 0.9913
#
# Testing momentum: 0.00
#
# Testing momentum: 0.50
#
# Testing momentum: 0.70
#
# Testing momentum: 0.80
#
# Testing momentum: 0.90
#
# Testing momentum: 0.95
#
# Testing momentum: 0.99
# ================================================================================
# EXPERIMENT 5: Projection vs Penalty Method Comparison
# ================================================================================
# Original features: 30
# After dropping: 24
# After PCA: 16
# Explained variance: 0.9913
#
# ================================================================================
# COMPARISON TABLE
# ================================================================================
#                Method Test Acc Test F1  Iterations Time (s) Converged  Num SV KKT Viol
# Projection (Nesterov)   0.9451  0.9531         574    0.068         ✓      42 8.08e+01
#  Penalty (weight=0.5)   0.9495  0.9576         355    0.042         ✓      30 9.09e+00
#    Penalty (weight=1)   0.9495  0.9576         316    0.033         ✓      30 1.04e+01
#    Penalty (weight=5)   0.9451  0.9533         333    0.038         ✓      28 1.33e+01
#   Penalty (weight=10)   0.9407  0.9493         304    0.037         ✓      29 1.59e+01
#   Penalty (weight=25)   0.9429  0.9513         430    0.047         ✓      26 1.31e+01
#   Penalty (weight=50)   0.9363  0.9454         307    0.037         ✓      28 1.65e+01
#  Penalty (weight=100)   0.9143  0.9249        2000    0.243         ✗      26 1.01e+03
# ================================================================================
# ALL EXPERIMENTS COMPLETED!
# ================================================================================
#
# Key Findings:
# 1. Best hyperparameters: {'C': 0.1, 'learning_rate': 1e-05, 'momentum': 0.9, 'use_nesterov': True}
# 2. Best test F1 score: 0.9606
# 3. Check output plots for detailed analysis
